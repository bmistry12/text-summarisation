# %%
import re
import nltk
import pickle
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# !python -m nltk.downloader stopwords wordnet punkt averaged_perceptron_tagger
from nltk.corpus import stopwords
from nltk.corpus import wordnet as wn
from nltk.stem import WordNetLemmatizer
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed, Bidirectional
from tensorflow.keras.layers import Attention
from keras.models import Model, load_model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences
from keras.optimizers import RMSprop
from sklearn.model_selection import train_test_split
# !pip install rouge
from rouge import Rouge

# %% [markdown]
# ### Hyperparameters

# %%
BATCH_SIZE=50
EPOCHS=50
latent_dim=128
embedding_dim=128
test_train_split=0.15
build_number="1"
LEARNING_RATE=0.001
max_text_len = 20
max_summary_len = 10
UNCOMMON_WORD_THRESHOLD = 100

# %%
# create rouge object for evaluation
rouge = Rouge()

# %% [markdown]
# ## Data Processing

# %% [markdown]
# Read In Data

# %%
# Only needed if running on Google Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('./drive/My Drive/Reviews.csv')
df.head(1)
# Out:
#    Id  ...                                               Text
# 0   1  ...  I have bought several of the Vitality canned d...
#
# [1 rows x 10 columns]

# %%
df = df.drop('Id', 1)
df = df.drop('ProductId', 1)
df = df.drop('UserId', 1)
df = df.drop('ProfileName', 1)
df = df.drop('HelpfulnessNumerator', 1)
df = df.drop('HelpfulnessDenominator', 1)
df = df.drop('Time', 1)
df = df.drop('Score', 1)
df.columns = ['summary', 'text']
df.head()
# Out:
#                  summary                                               text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
df.count
# Out:
# <bound method DataFrame.count of                                    summary                                               text
# 0                    Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1                        Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2                    "Delight" says it all  This is a confection that has been around a fe...
# 3                           Cough Medicine  If you are looking for the secret ingredient i...
# 4                              Great taffy  Great taffy at a great price.  There was a wid...
# ...                                    ...                                                ...
# 568449                 Will not do without  Great for sesame chicken..this is a good if no...
# 568450                        disappointed  I'm disappointed with the flavor. The chocolat...
# 568451            Perfect for our maltipoo  These stars are small, so you can give 10-15 o...
# 568452  Favorite Training and reward treat  These are the BEST treats for training and rew...
# 568453                         Great Honey  I am very satisfied ,product is as advertised,...
#
# [568454 rows x 2 columns]>

# %%
df.head()
# Out:
#                  summary                                               text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
# remove stop words
stop_words = set(stopwords.words('english'))
df['text'] = df['text'].apply(lambda x: nltk.word_tokenize(x)).apply(lambda x: " ".join([word for word in x if not word in stop_words]))
# df['summary'] = df['summary'].apply(lambda x: nltk.word_tokenize(x)).apply(lambda x: " ".join([word for word in x if not word in stop_words]))

# %%
df.head()
# Out:
#                  summary                                               text
# 0  Good Quality Dog Food  I bought several Vitality canned dog food prod...
# 1      Not as Advertised  Product arrived labeled Jumbo Salted Peanuts ....
# 2  "Delight" says it all  This confection around centuries . It light , ...
# 3         Cough Medicine  If looking secret ingredient Robitussin I beli...
# 4            Great taffy  Great taffy great price . There wide assortmen...

# %% [markdown]
# Remove .'s that appear in stuff like U.S.A and U.N - Eventually need to move this to dataprocessing.py

# %%
print(df['summary'][0])
df['summary'] = df['summary'].apply(lambda x: re.sub(r'\..*$',' ',str(x)))
print(df['summary'][0])
# Out:
# Good Quality Dog Food
# Good Quality Dog Food

# %%
print(df['text'][0])
df['text'] = df['text'].apply(lambda x: re.sub(r'\..*$',' ',str(x)))
print(df['text'][0])
# Out:
# I bought several Vitality canned dog food products found good quality . The product looks like stew processed meat smells better . My Labrador finicky appreciates product better .
# I bought several Vitality canned dog food products found good quality

# %%
print(df['summary'][0])
df['summary'] = df['summary'].apply(lambda x: re.sub(r'\.','',str(x)))
print(df['summary'][0])
print(df['text'][0])
df['text'] = df['text'].apply(lambda x: re.sub(r'\.','',str(x)))
print(df['text'][0])
# Out:
# Good Quality Dog Food
# Good Quality Dog Food
# I bought several Vitality canned dog food products found good quality
# I bought several Vitality canned dog food products found good quality

# %% [markdown]
# Check for rows with null values in them, and copy these into a new dataframe (df1). Drop any rows in df1 from df to ensure no NaN valued rows are present/
#
# *Note. using simply dropna(how='any') does not seem to drop any of the rows*

# %%
print(df.isnull().values.any())
print(df.shape)

df1 = df[df.isna().any(axis=1)]
print(df1.shape)

df.drop(df1.index, axis=0,inplace=True)
print(df.shape)
print(df.isnull().values.any())
# Out:
# False
# (568454, 2)
# (0, 2)
# (568454, 2)
# False

# %%
# only keep first x words (defined by max_text_len)
print(df['text'][0])
df['text'] = df['text'].apply(lambda x: nltk.word_tokenize(x)).apply(lambda x: " ".join(x[:max_text_len]))
print(df['text'][0])
# Out:
# I bought several Vitality canned dog food products found good quality
# I bought several Vitality canned dog food products found good quality

# %%
print(df['summary'][0])
df['summary'] = df['summary'].apply(lambda x: nltk.word_tokenize(x)).apply(lambda x: " ".join(x[:max_summary_len]))
print(df['summary'][0])
# Out:
# Good Quality Dog Food
# Good Quality Dog Food

# %% [markdown]
# Word Count Distribution

# %%
text_word_count = []
summary_word_count = []

# populate the lists with sentence lengths
for i in df['text']:
      text_word_count.append(len(i.split(' ')))

for i in df['summary']:
      summary_word_count.append(len(i.split(' ')))

length_df = pd.DataFrame({'text':text_word_count, 'summary':summary_word_count})

length_df.hist(bins = 30)
plt.ylabel('Documents')
plt.xlabel('Word Count')
# plt.savefig('word_count_distro' + str(build_number) + '.png')
plt.show()

# %% [markdown]
# Max Text Lengths

# %%
max_text_len = max([len(txt.split(' ')) for txt in df['text']])
max_summary_len = max([len(txt.split(' ')) for txt in df['summary']])
print(max_text_len)
print(max_summary_len)
# Out:
# 20
# 10

# %% [markdown]
# ### Removing Common Words

# %%
x_word_dict = {}
text = df['text'].apply(lambda x: nltk.word_tokenize(x))

for index, row in text.iteritems():
  for word in row:
    if word not in x_word_dict.keys():
      x_word_dict[word] = 1
    else:
      x_word_dict[word] += 1

print(len(x_word_dict))
x_sorted_dict = sorted(x_word_dict.items(), key=lambda x: x[1], reverse=True)
print(x_sorted_dict)
x, y = zip(*x_sorted_dict)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-20477f6b7f79> in <module>()
#       1 x_word_dict = {}
# ----> 2 text = df['text'].apply(lambda x: nltk.word_tokenize(x))
#       3
#       4 for index, row in text.iteritems():
#       5   for word in row:
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4043             else:
#    4044                 values = self.astype(object).values
# -> 4045                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4046
#    4047         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-55-20477f6b7f79> in <lambda>(x)
#       1 x_word_dict = {}
# ----> 2 text = df['text'].apply(lambda x: nltk.word_tokenize(x))
#       3
#       4 for index, row in text.iteritems():
#       5   for word in row:
#
# /usr/local/lib/python3.6/dist-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     126     :type preserver_line: bool
#     127     """
# --> 128     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     129     return [token for sent in sentences
#     130             for token in _treebank_word_tokenizer.tokenize(sent)]
#
# /usr/local/lib/python3.6/dist-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#      93     """
#      94     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
# ---> 95     return tokenizer.tokenize(text)
#      96
#      97 # Standard word tokenizer.
#
# /usr/local/lib/python3.6/dist-packages/nltk/tokenize/punkt.py in tokenize(self, text, realign_boundaries)
#    1235         Given a text, returns a list of the sentences in that text.
#    1236         """
# -> 1237         return list(self.sentences_from_text(text, realign_boundaries))
#    1238
#    1239     def debug_decisions(self, text):
#
# /usr/local/lib/python3.6/dist-packages/nltk/tokenize/punkt.py in sentences_from_text(self, text, realign_boundaries)
#    1283         follows the period.
#    1284         """
# -> 1285         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1286
#    1287     def _slices_from_text(self, text):
#
# /usr/local/lib/python3.6/dist-packages/nltk/tokenize/punkt.py in span_tokenize(self, text, realign_boundaries)
#    1274         if realign_boundaries:
#    1275             slices = self._realign_boundaries(text, slices)
# -> 1276         return [(sl.start, sl.stop) for sl in slices]
#    1277
#    1278     def sentences_from_text(self, text, realign_boundaries=True):
#
# /usr/local/lib/python3.6/dist-packages/nltk/tokenize/punkt.py in <listcomp>(.0)
#    1274         if realign_boundaries:
#    1275             slices = self._realign_boundaries(text, slices)
# -> 1276         return [(sl.start, sl.stop) for sl in slices]
#    1277
#    1278     def sentences_from_text(self, text, realign_boundaries=True):
#
# /usr/local/lib/python3.6/dist-packages/nltk/tokenize/punkt.py in _realign_boundaries(self, text, slices)
#    1314         """
#    1315         realign = 0
# -> 1316         for sl1, sl2 in _pair_iter(slices):
#    1317             sl1 = slice(sl1.start + realign, sl1.stop)
#    1318             if not sl2:
#
# /usr/local/lib/python3.6/dist-packages/nltk/tokenize/punkt.py in _pair_iter(it)
#     310     """
#     311     it = iter(it)
# --> 312     prev = next(it)
#     313     for el in it:
#     314         yield (prev, el)
#
# /usr/local/lib/python3.6/dist-packages/nltk/tokenize/punkt.py in _slices_from_text(self, text)
#    1289         for match in self._lang_vars.period_context_re().finditer(text):
#    1290             context = match.group() + match.group('after_tok')
# -> 1291             if self.text_contains_sentbreak(context):
#    1292                 yield slice(last_break, match.end())
#    1293                 if match.group('next_tok'):
#
# /usr/local/lib/python3.6/dist-packages/nltk/tokenize/punkt.py in text_contains_sentbreak(self, text)
#    1335         """
#    1336         found = False # used to ignore last token
# -> 1337         for t in self._annotate_tokens(self._tokenize_words(text)):
#    1338             if found:
#    1339                 return True
#
# /usr/local/lib/python3.6/dist-packages/nltk/tokenize/punkt.py in _annotate_second_pass(self, tokens)
#    1470         heuristic (4.1.2) and frequent sentence starter heuristic (4.1.3).
#    1471         """
# -> 1472         for t1, t2 in _pair_iter(tokens):
#    1473             self._second_pass_annotation(t1, t2)
#    1474             yield t1
#
# /usr/local/lib/python3.6/dist-packages/nltk/tokenize/punkt.py in _pair_iter(it)
#     310     """
#     311     it = iter(it)
# --> 312     prev = next(it)
#     313     for el in it:
#     314         yield (prev, el)
#
# /usr/local/lib/python3.6/dist-packages/nltk/tokenize/punkt.py in _annotate_first_pass(self, tokens)
#     579           - ellipsis_toks: The indices of all ellipsis marks.
#     580         """
# --> 581         for aug_tok in tokens:
#     582             self._first_pass_annotation(aug_tok)
#     583             yield aug_tok
#
# /usr/local/lib/python3.6/dist-packages/nltk/tokenize/punkt.py in _tokenize_words(self, plaintext)
#     549
#     550                 yield self._Token(next(line_toks),
# --> 551                         parastart=parastart, linestart=True)
#     552                 parastart = False
#     553
#
# /usr/local/lib/python3.6/dist-packages/nltk/tokenize/punkt.py in __init__(self, tok, **params)
#     388     __slots__ = ['tok', 'type', 'period_final'] + _properties
#     389
# --> 390     def __init__(self, tok, **params):
#     391         self.tok = tok
#     392         self.type = self._get_type(tok)
#
# KeyboardInterrupt:

# %%
# only accept words that occur more than 100 times
accept_words = []
for word, occ in x_sorted_dict:
  if int(occ) > UNCOMMON_WORD_THRESHOLD:
    accept_words.append(word)
  else:
    break
     
#remove first three comon words
# accept_words.remove(list(x[:3]))
accept_words = [x.lower() for x in accept_words]
print(accept_words)
print(df['text'][2])
df['text'] = df['text'].apply(lambda x: nltk.word_tokenize(x)).apply(lambda x: " ".join([word for word in x if word.lower() in accept_words]))
print(df['text'][2])
# Out:
# ['i', ',', '!', 'this', "'s", 'product', 'coffee', 'love', 'like', 'good', "n't", 'great', 'tea', 'my', 'taste', 'one', 'the', 'flavor', '(', 'these', '<', ')', 'food', "'ve", '>', 'best', '/', 'br', 'really', 'tried', "''", 'bought', 'dog', '``', 'time', 'find', 'would', 'we', '-', 'years', 'get', 'first', 'favorite', 'it', 'little', 'use', "'m", 'much', 'price', 'loves', 'amazon', 'buy', 'used', 'try', 'chocolate', 'ordered', 'delicious', 'found', 'eat', 'ever', ':', 'make', 'dogs', 'got', 'treats', 'drink', 'store', 'old', 'purchased', 'cat', 'chips', 'many', 'stuff', 'better', '&', 'two', 'always', 'cookies', 'brand', 'mix', 'if', 'since', 'could', 'free', 'well', 'snack', 'made', 'tastes', 'box', '2', 'order', 'sugar', 'year', 'cup', 'sweet', 'bars', 'local', 'even', 'say', 'great', 'water', 'day', 'different', 'cats', 'reviews', 'bag', 'every', 'hot', '?', 'tasty', 'healthy', 'products', 'thought', 'looking', 'tasting', 'flavors', 'way', 'never', 'quality', 'know', 'received', 'using', 'lot', '--', 'far', 'nice', 'give', 'a', 'go', '3', 'wonderful', 'ago', 'husband', 'hard', 'treat', 'perfect', 'loved', ';', 'ca', 'several', '$', 'eating', 'without', 'think', 'they', 'strong', 'cereal', 'tasted', 'family', 'excellent', 'item', 'buying', 'stores', 'something', 'bit', 'absolutely', 'enjoy', 'regular', 'new', 'review', 'makes', 'easy', 'grocery', 'salt', 'organic', 'candy', 'pretty', 'small', 'months', 'gluten', 'sauce', 'right', 'long', 'oil', 'fan', 'high', 'trying', 'arrived', 'diet', 'fresh', "'re", 'work', 'big', 'milk', 'want', '5', 'last', 'bad', 'when', 'son', 'coconut', 'came', 'popcorn', 'happy', 'pack', 'also', 'flavored', 'green', 'love', 'enough', 'gift', 'butter', 'package', 'morning', 'things', 'bags', '1', '4', 'purchase', 'keurig', 'quite', 'ingredients', 'back', 'wanted', 'low', 'daughter', 'need', 'almost', 'tea', 'whole', 'brands', 'bar', 'our', 'foods', 'thing', 'still', 'home', 'protein', 'size', 'keep', 'drinking', "'", 'month', 'decided', 'actually', 'recently', '6', 'sure', 'chicken', 'kids', 'variety', 'anything', 'real', 'as', 'after', 'teas', 'around', 'three', 'rice', 'getting', 'natural', 'usually', 'disappointed', 'started', 'coffee', 'available', 'less', 'peanut', 'love', 'liked', 'very', 'see', 'put', 'baby', 'wife', "'d", 'beans', 'especially', 'health', 'add', 'fruit', 'people', 'expensive', 'dark', 'friend', 'going', 'dry', 'enjoyed', 'amazing', 'snacks', 'take', 'not', 'texture', 'soup', 'read', 'blend', 'making', 'times', 'jerky', 'shipping', 'able', 'days', 'picky', 'full', 'deal', '//www', 'http', 'bread', 'black', 'vanilla', 'href=', 'calories', 'another', 'smell', '10', 'couple', 'market', 'so', 'breakfast', 'syrup', 'company', 'cheese', 'coffees', 'good', 'you', 'excited', 'house', 'for', 'green', 'come', 'awesome', 'gave', 'first', 'ones', 'just', 'feel', 'comes', 'quickly', "'ll", 'large', 'crackers', 'said', 'cups', 'pasta', 'the', 'must', 'fat', 'smooth', 'energy', 'kind', 'bold', '%', 'cookie', 'machine', 'alternative', 'past', 'quick', 'starbucks', 'definitely', 'fast', 'there', 'case', 'christmas', 'though', 'went', 'nothing', 'boxes', 'recommend', 'bitter', 'light', 'others', 'amount', 'what', 'packaging', 'puppy', 'pleased', 'us', 'seems', 'corn', 'away', 'works', 'ordering', 'gum', 'decaf', 'bottle', 'rich', 'surprised', 'reading', 'honey', 'money', 'fine', '12', 'saw', 'half', 'everything', 'expected', 'week', 'yet', 'drinks', 'help', 'chocolate', '8', 'meal', 'glad', 'powder', 'however', 'roast', 'oatmeal', 'canned', 'potato', 'probably', 'white', 'one', 'likes', 'nuts', 'yummy', 'online', 'wheat', 'says', 'worth', 'juice', 'least', 'exactly', 'granola', 'recommended', 'beef', 'added', 'look', 'discovered', 'amazon', 'may', 'start', 'live', 'value', 'per', 'life', 'and', 'type', 'dried', 'spicy', 'pods', 'took', 'this', 'fantastic', 'longer', 'drinker', 'eaten', 'seem', 'ginger', 'version', 'maker', 'organic', 'instant', 'crunchy', 'weeks', 'not', 'cocoa', 'cans', 'seco ...
# This confection around centuries
# This around

# %%
x_word_dict_after = {}
text = df['text'].apply(lambda x: nltk.word_tokenize(x))

for index, row in text.iteritems():
  for word in row:
    if word not in x_word_dict_after.keys():
      x_word_dict_after[word] = 1
    else:
      x_word_dict_after[word] += 1

print(len(x_word_dict_after))
# Out:
# 10310

# %%
y_word_dict = {}
text = df['summary'].apply(lambda x: nltk.word_tokenize(x))

for index, row in text.iteritems():
  for word in row:
    if word not in y_word_dict.keys():
      y_word_dict[word] = 1
    else:
      y_word_dict[word] += 1

print(len(y_word_dict))
y_sorted_dict = sorted(y_word_dict.items(), key=lambda x: x[1], reverse=True)
print(y_sorted_dict)
x, y = zip(*y_sorted_dict)
# Out:
# 58011
# [('!', 187382), (',', 60872), ('Great', 50237), ('the', 38805), ('for', 36638), ('and', 32914), ('a', 27120), ('Good', 24888), ('good', 24765), ('I', 23264), ('it', 23045), ('but', 21968), ('great', 19355), ('to', 19253), ('of', 18995), ('Best', 18396), ('is', 17113), ('this', 16702), ("'s", 16022), ('My', 15921), ('Not', 15094), ('coffee', 15089), ('not', 14771), ('product', 13659), ('The', 13288), ('Delicious', 12885), ('in', 12559), ('Love', 12379), ('tea', 12303), ('my', 12201), ('taste', 12047), ('A', 11940), ('best', 11829), ('?', 11790), ('love', 11444), ("n't", 11199), ('-', 11072), ('like', 10617), ('Excellent', 10309), ('Very', 9795), ('flavor', 9753), ('food', 9157), ('with', 9011), ('Coffee', 8993), ('Tea', 8961), ('you', 8615), ('these', 8484), ('dog', 8319), ('as', 8305), ('price', 7907), ('Yummy', 7069), ('on', 6885), ('are', 6864), ('It', 6830), ('favorite', 6591), ('This', 6188), ('&', 6149), ('Tasty', 6110), ('loves', 6008), ('stuff', 5978), ('ever', 5838), ('too', 5747), ('than', 5582), ('Product', 5471), ('snack', 5383), ('them', 5198), ('very', 5179), ('at', 5085), ('delicious', 5069), ('Taste', 4915), ('Dog', 4855), ('tasty', 4701), ('``', 4687), ("''", 4683), ('dogs', 4535), ('so', 4440), ('Awesome', 4306), ('better', 4111), ('what', 4045), ('Tastes', 3985), ('have', 3963), ('me', 3947), ('your', 3923), ('Wonderful', 3866), ('cat', 3864), (')', 3836), ('Perfect', 3812), ('from', 3761), ('Just', 3753), ('treat', 3744), ('be', 3707), ('that', 3703), ('tasting', 3598), ('Food', 3576), ('Nice', 3557), ('little', 3522), ('quality', 3519), ('all', 3486), ('These', 3484), ('healthy', 3430), ('LOVE', 3328), ('Flavor', 3305), ('bad', 3288), ('So', 3254), ('Yum', 3241), ('(', 3231), ('Healthy', 3220), ('buy', 3208), (':', 3187), ('No', 3150), ('do', 3113), ('was', 3084), ('Chocolate', 3071), ('sweet', 2996), ('Too', 2979), ('treats', 2972), ('chips', 2969), ('just', 2948), ('chocolate', 2940), ("'ve", 2892), ('BEST', 2879), ('cats', 2874), ('Better', 2834), ('or', 2785), ('Favorite', 2749), ('One', 2741), ('more', 2740), ('Really', 2713), ('one', 2713), ('out', 2688), ('Amazing', 2680), ('yummy', 2652), ('free', 2641), ('much', 2629), ('no', 2603), ('--', 2599), ('GREAT', 2590), ('Dogs', 2589), ('really', 2554), ('can', 2530), ('NOT', 2467), ('Price', 2463), ('Fantastic', 2450), ('Amazon', 2422), ('Cat', 2391), ('value', 2385), ('excellent', 2373), ('cup', 2345), ('Do', 2344), ('they', 2293), ('nice', 2278), ('hot', 2278), ('get', 2269), ('cookies', 2231), ('Organic', 2202), ('Sweet', 2189), ('For', 2175), ('Pretty', 2172), ('You', 2148), ('Ever', 2125), ('sugar', 2098), ('What', 2098), ('if', 2096), ('up', 2092), ('tastes', 2073), ('Free', 2070), ('Green', 2069), ('way', 2063), ('Like', 2039), ('eat', 2036), ('Hot', 2025), ('Snack', 2022), (';', 2019), ('mix', 1952), ('drink', 1940), ('Stuff', 1909), ('had', 1902), ('will', 1896), ('Quality', 1886), ('easy', 1885), ('Chips', 1873), ('does', 1863), ('an', 1826), ('only', 1812), ('THE', 1796), ('water', 1779), ('find', 1770), ('deal', 1767), ('If', 1733), ('Treats', 1726), ('by', 1725), ('cereal', 1713), ('Cats', 1700), ('there', 1693), ('perfect', 1675), ('candy', 1656), ('Easy', 1640), ('strong', 1635), ('salt', 1625), ('time', 1621), ('Treat', 1609), ('use', 1603), ('OK', 1598), ('alternative', 1587), ('expected', 1579), ('go', 1548), ('has', 1543), ('expensive', 1542), ('But', 1515), ('works', 1506), ('bar', 1501), ('Gluten', 1489), ("'", 1489), ('sauce', 1486), ('real', 1471), ('They', 1469), ('again', 1464), ('Cookies', 1450), ('Our', 1445), ('packaging', 1445), ('Works', 1440), ('Bad', 1425), ('wonderful', 1421), ('worth', 1416), ('Happy', 1413), ('other', 1408), ('Does', 1405), ('oil', 1395), ('without', 1383), ('popcorn', 1380), ('baby', 1375), ('bars', 1371), ('Sugar', 1369), ('Mix', 1368), ('money', 1352), ('YUM', 1331), ('old', 1329), ('would', 1318), ('EVER', 1316), ('made', 1312), ('awesome', 1305), ('service', 1303), ('5', 1300), ("'m", 1291), ('new' ...

# %%
# only accept words that occur more than 100 times
accept_words = []
for word, occ in y_sorted_dict:
  if int(occ) > UNCOMMON_WORD_THRESHOLD/2:
    accept_words.append(word)
  else:
    break
     
#remove first three comon words
# accept_words.remove(list(x[:3]))
accept_words = [x.lower() for x in accept_words]
print(accept_words)
print(df['summary'][2])
df['summary'] = df['summary'].apply(lambda x: nltk.word_tokenize(x)).apply(lambda x: " ".join([word for word in x if word.lower() in accept_words]))
print(df['summary'][2])
# Out:
# ['!', ',', 'great', 'the', 'for', 'and', 'a', 'good', 'good', 'i', 'it', 'but', 'great', 'to', 'of', 'best', 'is', 'this', "'s", 'my', 'not', 'coffee', 'not', 'product', 'the', 'delicious', 'in', 'love', 'tea', 'my', 'taste', 'a', 'best', '?', 'love', "n't", '-', 'like', 'excellent', 'very', 'flavor', 'food', 'with', 'coffee', 'tea', 'you', 'these', 'dog', 'as', 'price', 'yummy', 'on', 'are', 'it', 'favorite', 'this', '&', 'tasty', 'loves', 'stuff', 'ever', 'too', 'than', 'product', 'snack', 'them', 'very', 'at', 'delicious', 'taste', 'dog', 'tasty', '``', "''", 'dogs', 'so', 'awesome', 'better', 'what', 'tastes', 'have', 'me', 'your', 'wonderful', 'cat', ')', 'perfect', 'from', 'just', 'treat', 'be', 'that', 'tasting', 'food', 'nice', 'little', 'quality', 'all', 'these', 'healthy', 'love', 'flavor', 'bad', 'so', 'yum', '(', 'healthy', 'buy', ':', 'no', 'do', 'was', 'chocolate', 'sweet', 'too', 'treats', 'chips', 'just', 'chocolate', "'ve", 'best', 'cats', 'better', 'or', 'favorite', 'one', 'more', 'really', 'one', 'out', 'amazing', 'yummy', 'free', 'much', 'no', '--', 'great', 'dogs', 'really', 'can', 'not', 'price', 'fantastic', 'amazon', 'cat', 'value', 'excellent', 'cup', 'do', 'they', 'nice', 'hot', 'get', 'cookies', 'organic', 'sweet', 'for', 'pretty', 'you', 'ever', 'sugar', 'what', 'if', 'up', 'tastes', 'free', 'green', 'way', 'like', 'eat', 'hot', 'snack', ';', 'mix', 'drink', 'stuff', 'had', 'will', 'quality', 'easy', 'chips', 'does', 'an', 'only', 'the', 'water', 'find', 'deal', 'if', 'treats', 'by', 'cereal', 'cats', 'there', 'perfect', 'candy', 'easy', 'strong', 'salt', 'time', 'treat', 'use', 'ok', 'alternative', 'expected', 'go', 'has', 'expensive', 'but', 'works', 'bar', 'gluten', "'", 'sauce', 'real', 'they', 'again', 'cookies', 'our', 'packaging', 'works', 'bad', 'wonderful', 'worth', 'happy', 'other', 'does', 'oil', 'without', 'popcorn', 'baby', 'bars', 'sugar', 'mix', 'money', 'yum', 'old', 'would', 'ever', 'made', 'awesome', 'service', '5', "'m", 'new', 'our', 'low', 'far', 'bit', 'gluten', 'all', 'did', 'fresh', 'super', 'organic', 'kids', 'loves', 'gift', 'well', '$', 'green', 'about', 'absolutely', 'high', 'some', 'bold', 'enough', 'work', '2', 'make', 'good', 'right', 'dark', 'disappointed', 'natural', 'tasting', 'review', 'shipping', 'loved', 'coconut', 'ca', 'buy', 'fresh', 'even', 'strong', 'vanilla', 'salt', 'happy', 'makes', 'ca', 'it', 'found', 'popcorn', 'thing', 'small', 'hard', 'candy', 'wow', 'coconut', 'could', 'oil', 'ok', 'smooth', 'when', 'cookie', 'sauce', 'soup', 'item', 'chicken', 'milk', 'this', 'breakfast', 'protein', 'an', 'more', 'high', 'i', 'made', 'blend', 'amazing', 'only', '3', 'as', 'were', 'keurig', 'ingredients', 'decaf', 'did', 'pasta', 'size', 'yummy', 'salty', 'new', 'breakfast', 'finally', 'flavored', 'yum', 'bread', 'butter', 'we', 'bars', 'rice', 'chai', 'butter', 'flavors', 'blend', 'value', "'re", 'and', 'likes', 'decent', 'simply', 'loves', 'low', 'pretty', '1', 'convenient', 'decaf', 'k-cup', 'natural', 'hard', 'red', 'review', 'cereal', 'rice', 'terrible', 'first', 'tried', 'way', 'fabulous', 'starbucks', 'smooth', 'is', 'jerky', 'jerky', 'drink', 'energy', 'brand', 'we', 'long', 'bag', 'baby', 'k', 'to', 'disappointed', 'over', 'now', 'any', 'black', 'big', 'still', 'box', 'fast', 'substitute', 'beans', 'order', 'training', 'got', 'ginger', 'texture', 'light', 'gum', 'roast', 'weak', 'after', "'ll", 'real', 'okay', 'regular', 'gf', 'peanut', 'every', '4', 'dry', 'water', 'chip', 'smell', 'less', 'diet', 'formula', 'day', 'bar', 'same', 'picky', 'tasted', 'your', 'its', 'convenient', 'try', 'greenies', 'store', 'honey', 'horrible', 'okay', 'quick', 'crunchy', 'syrup', 'instant', 'big', 'dark', 'peanut', 'light', 'fine', 'nothing', '%', 'vanilla', 'market', 'back', 'most', 'very', 'spicy', 'energy', 'quick', 'much', 'down', 'used', 'beware', 'choice', 'for', 'bold', 'spicy', 'wow', 'stars', 'bags', 'awesome', 'sure', 'cup', 'want', 'delicious', 'worth', 'rich', 'f ...
# "Delight" says it all
# `` Delight '' says it all

# %%
y_word_dict_after = {}
summary = df['summary'].apply(lambda x: nltk.word_tokenize(x))

for index, row in summary.iteritems():
  for word in row:
    if word not in y_word_dict_after.keys():
      y_word_dict_after[word] = 1
    else:
      y_word_dict_after[word] += 1
print(len(y_word_dict_after))
# Out:
# 6723

# %%
text_word_count = []
summary_word_count = []

# populate the lists with sentence lengths
for i in df['text']:
      text_word_count.append(len(i.split(' ')))

for i in df['summary']:
      summary_word_count.append(len(i.split(' ')))

length_df = pd.DataFrame({'text':text_word_count, 'summary':summary_word_count})

length_df.hist(bins = 30)
plt.ylabel('Documents')
plt.xlabel('Word Count')
# plt.savefig('word_count_distro' + str(build_number) + '.png')
plt.show()

# %%
# update max text lengths
max_text_len = max([len(txt.split(' ')) for txt in df['text']])
max_summary_len = max([len(txt.split(' ')) for txt in df['summary']])
print(max_text_len)
print(max_summary_len)
# Out:
# 20
# 10

# %%
# drop any lines that have no text or summary after the word removal process
print(df.isnull().values.any())
print(df.shape)

df1 = df[df.isna().any(axis=1)]
print(df1.shape)

df.drop(df1.index, axis=0,inplace=True)
print(df.shape)
print(df.isnull().values.any())
# Out:
# False
# (568454, 2)
# (0, 2)
# (568454, 2)
# False

# %% [markdown]
# ### Training-Validation Split

# %% [markdown]
# X - Articles text </br>
# Y - Summaries

# %%
# convert to numpy array
X = np.array(df['text'])
Y = np.array(df['summary'])

# %%
x_tr,x_val,y_tr,y_val=train_test_split(X,Y,test_size=test_train_split,random_state=0,shuffle=True)
print(x_tr.shape)
print(x_val.shape)
print(y_tr.shape)
print(y_val.shape)
# Out:
# (483185,)
# (85269,)
# (483185,)
# (85269,)

# %% [markdown]
# ### Word Embeddings - Tokenization

# %% [markdown]
# X Tokenizer

# %%
word_dict = {}
text = df['text']

for row in text: 
  for word in row.split(" "):
    if word not in word_dict:
      word_dict[word] = 1
    else:
      word_dict[word] += 1

print(len(word_dict))
# Out:
# 10065

# %%
# #prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer(num_words=len(word_dict), split=" ") 
x_tokenizer.fit_on_texts(list(X))

#convert text sequences into integer sequences
x_tr_seq    =   x_tokenizer.texts_to_sequences(x_tr) 
x_val_seq   =   x_tokenizer.texts_to_sequences(x_val)

#padding zero upto maximum length
x_tr    =   pad_sequences(x_tr_seq,  maxlen=max_text_len, padding='post')
x_val   =   pad_sequences(x_val_seq, maxlen=max_text_len, padding='post')

#size of vocabulary ( +1 for padding token)
x_voc   =  x_tokenizer.num_words + 1
print(x_voc)
# Out:
# 10066

# %%
# with open('xtokenizer.pickle', 'wb') as handle:
#   pickle.dump(x_tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# Y Tokenizer

# %%
y_word_dict = {}
summ = df['summary']

for row in summ: 
  for word in row.split(" "):
    if word not in y_word_dict:
      y_word_dict[word] = 1
    else:
      y_word_dict[word] += 1

print(len(y_word_dict))
# Out:
# 6716

# %%
#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer(num_words=len(y_word_dict), split=" ") 
y_tokenizer.fit_on_texts(list(Y))

#convert text sequences into integer sequences
y_tr_seq    =   y_tokenizer.texts_to_sequences(y_tr) 
y_val_seq   =   y_tokenizer.texts_to_sequences(y_val) 

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr_seq, maxlen=max_summary_len, padding='post')
y_val   =   pad_sequences(y_val_seq, maxlen=max_summary_len, padding='post')

#size of vocabulary
y_voc  =   y_tokenizer.num_words + 1
print(y_voc)
# Out:
# 6717

# %%
# with open('ytokenizer.pickle', 'wb') as handle:
#   pickle.dump(y_tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Learning Model

# %% [markdown]
# #### Encoder Model

# %%
# bidirectional
encoder_inputs = Input(shape=(max_text_len,), name="encoder_input")
#embedding layer
enc_emb =  Embedding(x_voc,embedding_dim,trainable=True,name="encoder_embedding")(encoder_inputs)
#encoder lstm 
encoder_lstm = Bidirectional(LSTM(latent_dim,return_sequences=True,return_state=True, name="bidirectional_lstm"))
encoder_outputs, fw_state_h, fw_state_c, bw_state_h, bw_state_c = encoder_lstm(enc_emb)

state_h = Concatenate()([fw_state_h, bw_state_h])
state_c = Concatenate()([fw_state_c, bw_state_c])
encoder_states = [state_h, state_c]

# %% [markdown]
# #### Decoder Model

# %%
# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None,), name="decoder_input")

#embedding layer
dec_emb_layer = Embedding(y_voc, embedding_dim,trainable=True,name="decoder_embedding")
dec_emb = dec_emb_layer(decoder_inputs)

decoder_lstm = LSTM(latent_dim*2, return_sequences=True, return_state=True, name="decoder_lstm")
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=encoder_states)
                                                          
#dense layer
decoder_dense = Dense(y_voc, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %% [markdown]
# #### Combined LSTM Model

# %%
# Define the model 
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      (None, 20)           0
# __________________________________________________________________________________________________
# encoder_embedding (Embedding)   (None, 20, 128)      1288448     encoder_input[0][0]
# __________________________________________________________________________________________________
# decoder_input (InputLayer)      (None, None)         0
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) [(None, 20, 256), (N 263168      encoder_embedding[0][0]
# __________________________________________________________________________________________________
# decoder_embedding (Embedding)   (None, None, 128)    859776      decoder_input[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256)          0           bidirectional_2[0][1]
#                                                                  bidirectional_2[0][3]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 256)          0           bidirectional_2[0][2]
#                                                                  bidirectional_2[0][4]
# __________________________________________________________________________________________________
# decoder_lstm (LSTM)             [(None, None, 256),  394240      decoder_embedding[0][0]
#                                                                  concatenate_3[0][0]
#                                                                  concatenate_4[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, None, 6717)   1726269     decoder_lstm[0][0]
# ==================================================================================================
# Total params: 4,531,901
# Trainable params: 4,531,901
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
optimizer = RMSprop(lr=LEARNING_RATE, rho=0.9)

# %%
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy')

# %% [markdown]
# - Early Stopping Callback to ensure we stop when Validation Loss is lowest - minimises risk of overfitting
# - Model Checkpoint saves the model after each epoch so that we can load the model with the best weights later on. Alternatively, it allows us to continue training the model at a later data

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=2, restore_best_weights=False)
filepath = "./drive/My Drive/project-model/saved-model-{epoch:02d}.hdf5"
mc = ModelCheckpoint(filepath, monitor='val_loss', verbose=0, save_best_only=False, save_weights_only=False, mode='auto', period=1)

# %% [markdown]
# #### Use this method to train a new model. To continue training a previously trained model see below

# %%
y_tr_3d = y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:]
y_val_3d = y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:]

# %%
print(x_tr.shape)
print(y_tr.shape)
print(y_tr_3d.shape)
print(x_val.shape)
print(y_val.shape)
print(y_val_3d.shape)
# Out:
# (483185, 20)
# (483185, 10)
# (483185, 9, 1)
# (85269, 20)
# (85269, 10)
# (85269, 9, 1)

# %%
history = model.fit([x_tr,y_tr[:,:-1]], y_tr_3d, batch_size=BATCH_SIZE, epochs=EPOCHS, callbacks=[es], 
                    validation_data=([x_val,y_val[:,:-1]], y_val_3d))
# Out:
# Train on 483185 samples, validate on 85269 samples
# Epoch 1/50
# 483185/483185 [==============================] - 884s 2ms/step - loss: 1.5459 - val_loss: 1.4144
# Epoch 2/50
# 483185/483185 [==============================] - 881s 2ms/step - loss: 1.3771 - val_loss: 1.3689
# Epoch 3/50
# 483185/483185 [==============================] - 875s 2ms/step - loss: 1.3341 - val_loss: 1.3383
# Epoch 4/50
# 483185/483185 [==============================] - 868s 2ms/step - loss: 1.3047 - val_loss: 1.3242
# Epoch 5/50
# 483185/483185 [==============================] - 867s 2ms/step - loss: 1.2843 - val_loss: 1.3134
# Epoch 6/50
# 483185/483185 [==============================] - 862s 2ms/step - loss: 1.2640 - val_loss: 1.3054
# Epoch 7/50
# 483185/483185 [==============================] - 859s 2ms/step - loss: 1.2500 - val_loss: 1.3033
# Epoch 8/50
# 483185/483185 [==============================] - 866s 2ms/step - loss: 1.2356 - val_loss: 1.2998
# Epoch 9/50
# 483185/483185 [==============================] - 868s 2ms/step - loss: 1.2205 - val_loss: 1.2972
# Epoch 10/50
# 483185/483185 [==============================] - 871s 2ms/step - loss: 1.2095 - val_loss: 1.2915
# Epoch 11/50
# 483185/483185 [==============================] - 869s 2ms/step - loss: 1.1962 - val_loss: 1.2872
# Epoch 12/50
# 483185/483185 [==============================] - 867s 2ms/step - loss: 1.1902 - val_loss: 1.2958
# Epoch 13/50
# 483185/483185 [==============================] - 869s 2ms/step - loss: 1.1886 - val_loss: 1.3011
# Epoch 00013: early stopping

# %% [markdown]
# #### This method is to only be used when loading a previously partially trained model

# %%
# model = load_model("./drive/My Drive/project-model/saved-model-53.hdf5")
# history = model.fit([x_tr,y_tr[:,:-1]], y_tr, callbacks=[mc], batch_size=BATCH_SIZE, epochs=1, validation_data=([x_val,y_val[:,:-1]], y_val))

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
# plt.savefig('loss' + str(build_number) + '.png')
plt.show()

# %% [markdown]
# ## Inference Model

# %%
# load model from drive
# model = load_model("./drive/My Drive/saved-model-53.hdf5")

# %%
reverse_target_word_index=y_tokenizer.index_word
reverse_source_word_index=x_tokenizer.index_word
print(reverse_source_word_index)
print(reverse_target_word_index)
# Out:
# {1: 'i', 2: 'this', 3: 'love', 4: 'coffee', 5: 'product', 6: "'s", 7: 'great', 8: 'good', 9: 'like', 10: 'tea', 11: "n't", 12: 'my', 13: 'one', 14: 'the', 15: 'taste', 16: 'these', 17: 'flavor', 18: 'best', 19: 'food', 20: "'ve", 21: 'really', 22: 'tried', 23: 'bought', 24: 'dog', 25: "''", 26: 'first', 27: 'time', 28: 'find', 29: 'we', 30: 'years', 31: 'would', 32: 'br', 33: 'get', 34: 'favorite', 35: 'it', 36: 'loves', 37: 'amazon', 38: 'chocolate', 39: 'little', 40: 'use', 41: 'much', 42: 'price', 43: "'m", 44: 'delicious', 45: 'used', 46: 'ordered', 47: 'buy', 48: 'free', 49: 'found', 50: 'try', 51: 'ever', 52: 'got', 53: 'dogs', 54: 'eat', 55: 'chips', 56: 'cup', 57: 'treats', 58: 'purchased', 59: 'make', 60: 'old', 61: 'cat', 62: 'drink', 63: 'store', 64: 'many', 65: 'stuff', 66: 'since', 67: 'two', 68: 'mix', 69: 'well', 70: 'better', 71: 'k', 72: 'cookies', 73: 'tastes', 74: 'sugar', 75: 'if', 76: 'always', 77: 'brand', 78: '2', 79: 'bars', 80: 'could', 81: 'made', 82: 'snack', 83: 'hot', 84: 'year', 85: 'sweet', 86: 'box', 87: 'order', 88: 'even', 89: 'cats', 90: 'local', 91: 'every', 92: 'received', 93: 'water', 94: 'gluten', 95: 'tasty', 96: 'excellent', 97: 'say', 98: 'day', 99: 'reviews', 100: 'healthy', 101: 'different', 102: 'thought', 103: 'products', 104: 'looking', 105: 'never', 106: 'green', 107: 'tasting', 108: 'nice', 109: 'quality', 110: 'bag', 111: 'cups', 112: 'wonderful', 113: 'way', 114: 'lot', 115: 'organic', 116: 'loved', 117: 'using', 118: 'flavors', 119: 'far', 120: 'know', 121: 'go', 122: 'perfect', 123: '3', 124: 'hard', 125: 'ca', 126: 'husband', 127: 'give', 128: 'ago', 129: 'a', 130: 'new', 131: 'treat', 132: 'several', 133: 'absolutely', 134: 'salt', 135: 'cereal', 136: 'item', 137: 'strong', 138: 'eating', 139: 'they', 140: 'think', 141: 'tasted', 142: 'easy', 143: 'without', 144: 'family', 145: 'coconut', 146: 'sauce', 147: 'diet', 148: 'big', 149: 'oil', 150: 'buying', 151: 'enjoy', 152: 'makes', 153: 'stores', 154: 'candy', 155: 'regular', 156: 'review', 157: 'arrived', 158: 'butter', 159: 'high', 160: 'pretty', 161: 'bit', 162: 'fresh', 163: 'grocery', 164: 'something', 165: 'fan', 166: 'pack', 167: 'happy', 168: '1', 169: 'months', 170: 'trying', 171: 'popcorn', 172: 'small', 173: 'milk', 174: 'whole', 175: 'long', 176: 'foods', 177: 'not', 178: 'last', 179: 'when', 180: '5', 181: 'low', 182: 'son', 183: 'right', 184: 'chicken', 185: 'came', 186: 'natural', 187: 'keurig', 188: 'flavored', 189: 'bad', 190: 'work', 191: 'gift', 192: 'dark', 193: 'want', 194: "'re", 195: 'very', 196: '4', 197: 'package', 198: 'bar', 199: 'bags', 200: 'morning', 201: 'quite', 202: 'things', 203: 'blend', 204: 'also', 205: 'wanted', 206: 'enough', 207: 'daughter', 208: 'purchase', 209: 'rice', 210: 'vanilla', 211: 'our', 212: 'peanut', 213: 'back', 214: 'ingredients', 215: 'almost', 216: 'recently', 217: 'protein', 218: 'kind', 219: 'black', 220: 'as', 221: 'baby', 222: 'brands', 223: 'real', 224: 'need', 225: 'home', 226: 'fruit', 227: 'drinking', 228: 'variety', 229: 'actually', 230: 'size', 231: 'decided', 232: 'month', 233: 'teas', 234: 'thing', 235: 'amazing', 236: 'kids', 237: 'still', 238: 'after', 239: 'keep', 240: 'people', 241: 'sure', 242: 'usually', 243: 'beans', 244: 'three', 245: 'started', 246: "'", 247: 'disappointed', 248: 'breakfast', 249: 'jerky', 250: 'anything', 251: '6', 252: 'wife', 253: 'health', 254: 'for', 255: 'liked', 256: 'getting', 257: 'around', 258: 'dry', 259: 'see', 260: 'available', 261: 'especially', 262: 'put', 263: 'soup', 264: 'so', 265: 'roast', 266: 'enjoyed', 267: 'friend', 268: 'less', 269: 'snacks', 270: 'house', 271: 'read', 272: 'full', 273: 'bold', 274: "'d", 275: 'expensive', 276: 'awesome', 277: 'market', 278: 'add', 279: 'bread', 280: 'going', 281: 'take', 282: 'honey', 283: 'cheese', 284: 'us', 285: 'light', 286: 'picky', 287: 'you', 288: 'texture', 289: 'ok', 290: 'energy', 291: 'another', 292: 'times', 293: 'deal', 294: 'shipping', 295: 'syrup', 296: 'abl ...
# {1: 'great', 2: 'the', 3: 'good', 4: 'for', 5: 'a', 6: 'and', 7: 'best', 8: 'not', 9: 'it', 10: 'my', 11: 'love', 12: 'coffee', 13: 'i', 14: 'but', 15: 'this', 16: 'tea', 17: 'to', 18: 'product', 19: 'of', 20: 'delicious', 21: 'is', 22: 'taste', 23: "'s", 24: 'very', 25: 'dog', 26: 'in', 27: 'excellent', 28: 'flavor', 29: 'food', 30: 'like', 31: 'these', 32: "n't", 33: 'tasty', 34: 'yummy', 35: 'you', 36: 'price', 37: 'with', 38: 'favorite', 39: 'as', 40: 'ever', 41: 'too', 42: 'so', 43: 'loves', 44: 'stuff', 45: 'snack', 46: 'on', 47: 'are', 48: 'dogs', 49: 'better', 50: 'healthy', 51: 'just', 52: 'awesome', 53: 'cat', 54: 'what', 55: 'no', 56: 'chocolate', 57: 'free', 58: 'tastes', 59: 'than', 60: 'do', 61: 'nice', 62: 'them', 63: 'perfect', 64: 'wonderful', 65: 'yum', 66: 'really', 67: 'quality', 68: 'one', 69: 'treat', 70: 'at', 71: 'sweet', 72: 'chips', 73: 'all', 74: 'tasting', 75: 'bad', 76: 'cup', 77: 'buy', 78: 'treats', 79: 'have', 80: 'your', 81: 'hot', 82: 'me', 83: 'cats', 84: 'k', 85: 'be', 86: "''", 87: 'amazing', 88: 'little', 89: 'from', 90: 'that', 91: 'if', 92: 'cookies', 93: 'sugar', 94: 'gluten', 95: 'they', 96: 'easy', 97: 'more', 98: 'organic', 99: 'was', 100: 'value', 101: 'much', 102: 'green', 103: 'mix', 104: 'does', 105: 'fantastic', 106: 'way', 107: 'ok', 108: 'can', 109: 'out', 110: 'pretty', 111: 'works', 112: 'only', 113: "'ve", 114: 'candy', 115: 'an', 116: 'strong', 117: 'salt', 118: 'drink', 119: 'our', 120: 'or', 121: 'get', 122: 'up', 123: 'amazon', 124: 'cereal', 125: 'sauce', 126: 'happy', 127: 'popcorn', 128: 'water', 129: 'deal', 130: 'oil', 131: 'made', 132: 'cups', 133: 'real', 134: 'fresh', 135: 'low', 136: 'new', 137: 'eat', 138: 'bars', 139: 'will', 140: 'bar', 141: 'ca', 142: 'high', 143: 'coconut', 144: 'go', 145: 'did', 146: 'had', 147: 'baby', 148: 'there', 149: 'expensive', 150: 'natural', 151: 'worth', 152: 'time', 153: 'alternative', 154: 'review', 155: 'disappointed', 156: 'find', 157: 'hard', 158: 'breakfast', 159: 'wow', 160: 'by', 161: 'bold', 162: 'use', 163: 'decaf', 164: 'smooth', 165: 'blend', 166: 'gift', 167: 'dark', 168: 'service', 169: 'loved', 170: 'packaging', 171: 'super', 172: 'butter', 173: 'has', 174: 'vanilla', 175: 'old', 176: 'rice', 177: 'some', 178: 'we', 179: 'expected', 180: 'makes', 181: 'would', 182: 'kids', 183: 'jerky', 184: 'well', 185: 'soup', 186: 'big', 187: 'chicken', 188: 'money', 189: 'cookie', 190: 'convenient', 191: 'shipping', 192: 'energy', 193: 'protein', 194: 'pasta', 195: 'again', 196: 'bread', 197: 'far', 198: 'absolutely', 199: 'without', 200: 'light', 201: 'milk', 202: 'terrible', 203: 'fast', 204: 'okay', 205: 'peanut', 206: 'make', 207: 'small', 208: 'other', 209: 'could', 210: 'horrible', 211: 'even', 212: 'quick', 213: 'spicy', 214: 'salty', 215: "'", 216: 'right', 217: 'crunchy', 218: 'item', 219: 'weak', 220: 'beans', 221: 'work', 222: 'first', 223: 'about', 224: 'chai', 225: 'syrup', 226: 'enough', 227: 'black', 228: 'found', 229: 'instant', 230: 'ginger', 231: 'beware', 232: 'roast', 233: 'flavored', 234: 'dry', 235: 'decent', 236: 'bit', 237: 'honey', 238: 'addictive', 239: 'still', 240: 'ingredients', 241: 'thing', 242: "'m", 243: 'try', 244: 'gum', 245: 'nothing', 246: 'choice', 247: 'finally', 248: 'flavors', 249: 'bitter', 250: 'poor', 251: 'fruit', 252: 'cocoa', 253: 'when', 254: '5', 255: 'stale', 256: 'now', 257: 'never', 258: 'diet', 259: 'most', 260: 'rich', 261: 'chip', 262: 'got', 263: 'oatmeal', 264: '2', 265: 'size', 266: 'cheese', 267: 'refreshing', 268: 'must', 269: 'fabulous', 270: 'formula', 271: 'its', 272: 'awful', 273: 'red', 274: 'spice', 275: 'always', 276: 'health', 277: 'flavorful', 278: 'simply', 279: 'long', 280: 'tried', 281: 'kind', 282: 'wrong', 283: 'different', 284: 'picky', 285: 'fun', 286: 'quite', 287: 'training', 288: 'less', 289: 'fine', 290: 'crackers', 291: 'pack', 292: 'bags', 293: 'beef', 294: 'brand', 295: 'over', 296: 'likes', 297: 'substitute', 298: 'bag', 299: 'were', 300: 'keur ...

# %%
# Encode the input sequence to get the feature vector
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# %%
encoder_model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      (None, 20)           0
# __________________________________________________________________________________________________
# encoder_embedding (Embedding)   (None, 20, 128)      1288448     encoder_input[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) [(None, 20, 256), (N 263168      encoder_embedding[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256)          0           bidirectional_2[0][1]
#                                                                  bidirectional_2[0][3]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 256)          0           bidirectional_2[0][2]
#                                                                  bidirectional_2[0][4]
# ==================================================================================================
# Total params: 1,551,616
# Trainable params: 1,551,616
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Decoder setup
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim*2,))
decoder_state_input_c = Input(shape=(latent_dim*2,))
decoder_hidden_state_input = Input(shape=(max_text_len,latent_dim*2))
decoder_state_inputs = [decoder_state_input_h, decoder_state_input_c]

# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs) 
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=decoder_state_inputs)
decoder_states = [state_h2, state_c2]
# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_outputs2) 

# Final decoder model
decoder_model = Model([decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c], [decoder_outputs2] + decoder_states)
# decoder_model = Model([decoder_inputs] + decoder_state_inputs, [decoder_outputs2] + decoder_states)

# %%
decoder_model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# decoder_input (InputLayer)      (None, None)         0
# __________________________________________________________________________________________________
# decoder_embedding (Embedding)   (None, None, 128)    859776      decoder_input[0][0]
# __________________________________________________________________________________________________
# input_1 (InputLayer)            (None, 256)          0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 256)          0
# __________________________________________________________________________________________________
# decoder_lstm (LSTM)             [(None, None, 256),  394240      decoder_embedding[1][0]
#                                                                  input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, None, 6717)   1726269     decoder_lstm[1][0]
# ==================================================================================================
# Total params: 2,980,285
# Trainable params: 2,980,285
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Methods for Reversing Word Embeddings

# %%
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString=newString+reverse_source_word_index[i]+' '
    return newString

# %% [markdown]
# ### Summarisation Method

# %%
def decode_sequence(input_seq): 
    # Encode the input as state vectors.
    # print(input_seq)
    # print(input_seq.shape)
    e_out, e_h, e_c = encoder_model.predict(input_seq)
    target_seq = np.zeros((1, y_voc))
    # print(target_seq.shape)
    stop_condition = False
    decoded_sentence = ''
    last_token = 0
    while not stop_condition:
      # Model([decoder_inputs] + decoder_state_inputs, [decoder_outputs2] + decoder_states)
      output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c]) 
      sampled_token_index = np.argmax(output_tokens[0, -1, :][1:])
      if(sampled_token_index == last_token):
        a = np.delete(output_tokens[0, -1, :][1:], sampled_token_index)
        sampled_token_index=np.argmax(a)
        if sampled_token_index >= last_token :
          sampled_token_index = sampled_token_index+1 
      # print(sampled_token_index)
      # print(sampled_token_index)
      last_token = sampled_token_index
      if (sampled_token_index != 0 ):
        sampled_token = reverse_target_word_index[sampled_token_index]
        # print(sampled_token)
        decoded_sentence += ' '+sampled_token
      else :
        print("sadface")
        stop_condition = True
      if (len(decoded_sentence.split()) >= (max_summary_len-1)):
              stop_condition = True
       # Update the target sequence (of length 1).
      # target_seq = np.zeros((1,1))
      target_seq = np.zeros((1, y_voc))
      target_seq[0, sampled_token_index] = 1
      # print(target_seq)
      # Update internal states
      e_h, e_c = h, c
      
    return decoded_sentence

# %% [markdown]
# ## Test Model Output

# %% [markdown]
# Note: *I think there isn't enough data being passed in and so the argmax value always is 0 - it can't learn what should be next*

# %%
def getRouge(gt, pred):
  return rouge.get_scores(pred, gt)

# %%
for i in range(0,2):
    print("Article:",seq2text(x_tr[i]))
    original = seq2summary(y_tr[i])
    if (original !=""):
      print("Original summary:",original)
      a = x_tr[i].reshape(1,max_text_len)
      summary = decode_sequence(a)
      print("Generated summary:",summary)
      print("\n")

      if summary != "":    
        print("ROUGE score: ")
        score = getRouge(str(summary), str(original))
        print(score)
        print(score[0].get('rouge-1').get('f'))
        print(score[0].get('rouge-1').get('p'))
        print(score[0].get('rouge-1').get('r'))
# Out:
# Article: wow i thrilled coffee
# Original summary: so happy i found these
# Generated summary:  price a price great price a price a price
#
#
# ROUGE score:
# [{'rouge-1': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.0, 'p': 0.0, 'r': 0.0}}]
# 0.0
# 0.0
# 0.0
# Article: popchips chip i love original best i wish would make sodium free though
# Original summary: my 1 guilty pleasure
# Generated summary:  most price i price i price a price a
#
#
# ROUGE score:
# [{'rouge-1': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.0, 'p': 0.0, 'r': 0.0}}]
# 0.0
# 0.0
# 0.0

# %%
for i in range(2479,2484):
    print("Article:",seq2text(x_tr[i]))
    original = seq2summary(y_tr[i])
    if (original !=""):
      print("Original summary:",original)
      a = x_tr[i].reshape(1,max_text_len)
      summary = decode_sequence(a)
      print("Generated summary:",summary)
      print("\n")

      if summary != "":    
        print("ROUGE score: ")
        score = getRouge(str(summary), str(original))
        print(score)
        print(score[0].get('rouge-1').get('f'))
        print(score[0].get('rouge-1').get('p'))
        print(score[0].get('rouge-1').get('r'))
# Out:
# Article: i love hot cocoa mix
# Original summary: absolutely the best hot chocolate ever
# Generated summary:  a i a i a price a price a
#
#
# ROUGE score:
# [{'rouge-1': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.0, 'p': 0.0, 'r': 0.0}}]
# 0.0
# 0.0
# 0.0
# Article: according wife one best k cup bought also first used
# Original summary: caribou coffee k cup
# Generated summary:  a i price a price a price a price
#
#
# ROUGE score:
# [{'rouge-1': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.0, 'p': 0.0, 'r': 0.0}}]
# 0.0
# 0.0
# 0.0
# Article: this fine maker top five see store
# Original summary: fine mustard poor pricing
# Generated summary:  a i a i price a price a price
#
#
# ROUGE score:
# [{'rouge-1': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.0, 'p': 0.0, 'r': 0.0}}]
# 0.0
# 0.0
# 0.0
# Article: this easily become favorite flavored coffee from moment brewing last sip cup i usually save flavored coffees
# Original summary: flavor aroma
# Generated summary:  a i price the price a price a price
#
#
# ROUGE score:
# [{'rouge-1': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.0, 'p': 0.0, 'r': 0.0}}]
# 0.0
# 0.0
# 0.0
# Article: unlike medium i purchased fresh
# Original summary: fresh
# Generated summary:  price a price a price a price a price
#
#
# ROUGE score:
# [{'rouge-1': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-2': {'f': 0.0, 'p': 0.0, 'r': 0.0}, 'rouge-l': {'f': 0.0, 'p': 0.0, 'r': 0.0}}]
# 0.0
# 0.0
# 0.0

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Using ROUGE (Recall-Orientated Understanding Gisting Evaluation) to evaluate the generated summaries.
#
# *Note: This takes a long time, especially with large datasets*

# %%
def get_overlapping_words(x, y):
  num=0
  x = nltk.word_tokenize(x)
  y = nltk.word_tokenize(y)
  for word in y:
    if word in x:
      num = num+1
      x.remove(word)
    else:
      return num

def precision(target, generated):
  length = len(target)
  for i in range (0, length):
    num_overlapping_words = get_overlapping_words(target[i], generated[i])
    generated_summary_len = len(generated[i])
    if generated_summary_len == 0 :
        return 0.0
    else : 
      return num_overlapping_words / generated_summary_len

# %% [markdown]
# ### For Training Data

# %%
print(len(x_tr))
# Out:
# 483185

# %%
tr_target_summary = []
tr_generated_summary = []
x_tr_len = len(x_tr)

f_ov = 0
p_ov = 0
r_ov = 0
# x_val_len = 1
for i in range(0,x_tr_len):
  original = seq2summary(y_tr[i])
  tr_target_summary.append(original)
  x_i = x_tr[i].reshape(1,max_text_len)
  summary = decode_sequence(x_i)
  tr_generated_summary.append(summary)
  score = getRouge(str(summary), str(original))
  f_ov += float(score[0].get('rouge-1').get('f'))
  p_ov += float(score[0].get('rouge-1').get('p'))
  r_ov += float(score[0].get('rouge-1').get('r'))

# %%
# print("precision : " + str(precision(tr_target_summary, tr_generated_summary)))
print("Avg F Score: " + str(f_ov/x_tr_len))
print("Avg Precision: " + str(p_ov/x_tr_len))
print("Avg Recall: " + str(r_ov/x_tr_len))

# %% [markdown]
# ### For Validation Data

# %%
val_target_summary = []
val_generated_summary = []
x_val_len = len(x_val)
f_ov = 0
p_ov = 0
r_ov = 0

for i in range(0,x_val_len):
  original = seq2summary(y_val[i])
  val_target_summary.append(original)
  x_i = x_val[i].reshape(1,max_text_len)
  summary = decode_sequence(x_i)
  val_generated_summary.append(summary)
  score = getRouge(str(summary), str(original))
  f_ov += float(score[0].get('rouge-1').get('f'))
  p_ov += float(score[0].get('rouge-1').get('p'))
  r_ov += float(score[0].get('rouge-1').get('r'))

# %%
# print("precision : " + str(precision(val_target_summary, val_generated_summary)))
print("Avg F Score: " + str(f_ov/x_val_len))
print("Avg Precision: " + str(p_ov/x_val_len))
print("Avg Recall: " + str(r_ov/x_val_len))

# %% [markdown]
# # Inputting New Data

# %%
def getpos(word):
  pos = nltk.pos_tag([word])[0][1][0]
  wordnet_conv = {"J": wn.ADJ, "N": wn.NOUN, "V": wn.VERB, "R": wn.ADV}
  if pos in wordnet_conv.keys():
    return wordnet_conv.get(pos)
  return ""

# %%
def lemmatization(text):
  lemmatizer = WordNetLemmatizer()
  text_tokenized = inp_df['text'].apply(lambda x: nltk.word_tokenize(x))
  print("lemmatize with pos")
  for i in range(0,len(text_tokenized)):
    text_lemmatized = []
    for word in text_tokenized[i]:
      pos = getpos(word)
      if pos != "":
        lemma = lemmatizer.lemmatize(word, pos)
        text_lemmatized.append(lemma)
      else :
        text_lemmatized.append(word)
    text_lemmatized = ' '.join(map(str, text_lemmatized))
    inp_df['text'][i] = text_lemmatized

# %%
# input1 = "(CNN) — Earlier this year, Delta Air Lines announced a rethink on reclining seats. In an effort to disrupt fewer passengers' travel experiences, Delta said it'd begin revamping some of its jets to reduce the recline of coach seats from four inches to two inches and the recline of first class seats from 5.5 inches to 3.5 inches. For those who abhor the recline option, it's a small step. And for those who value it, well, it's a compromise. This seemingly innocuous topic is one where there are very much two minds on what's acceptable and what's not. Two CNN Travel staffers engage in a friendly debate about seat recline. Your seat. Your decision. Stacey Lastoe, senior editor at CNN Travel, is of above-average height and makes no apology about reclining; it's her right as a plane, train and bus passenger. She encourages the person sitting in front of her to recline as well. On the first leg of my flight to Japan for my honeymoon, my husband and I got upgraded to first class. Although it would just be a few hours in the sky en route to Dallas, I was excited about sipping Champagne, sitting back and relaxing. Flute in hand, I pushed back to recline my seat for maximum relaxation. But it would not budge; I appeared to be stuck in a dysfunctional seat. Or was I? Turns out the gentleman behind me had a dog in a crate down between his legs, positioned so the seat in front of his -- my seat -- had nowhere to go. Because we were newlyweds and loving every moment of it, I did not mind when my husband turned to the man and told him his wife wanted to recline her seat and asked if he could please rearrange his dog crate to allow for everyones comfort."
input1 = "Its official US President Barack Obama want lawmaker weigh whether use military force Syria Obama sent letter head House Senate Saturday night hour announce believe military action Syrian target right step take allege use chemical weapon The propose legislation Obama asks Congress approve use military force deter disrupt prevent degrade potential future us chemical weapon weapon mass destruction Its step set turn international crisis fierce domestic political battle There key question loom debate What UN weapon inspector find Syria What happens Congress vote And Syrian government react In televise address White House Rose Garden earlier Saturday president say would take case Congress want While I believe I authority carry military action without specific congressional authorization I know country strong take course action even effective say We debate issue big business usual Obama say top congressional leader agree schedule debate body return Washington September 9 The Senate Foreign Relations Committee hold hearing matter Tuesday Sen Robert Menendez say Transcript Read Obamas full remark Syrian crisis Latest development UN inspector leave Syria Obamas remark come shortly UN inspector left Syria carry evidence determine whether chemical weapon use attack early last week Damascus suburb The aim game mandate clear ascertain whether chemical weapon use UN spokesman Martin Nesirky told reporter Saturday But use weapon report toxic gas attack Damascus suburb August 21 key point global debate Syrian crisis Top US official say there doubt Syrian government behind Syrian official deny responsibility blame jihadist fight rebel British US intelligence report say attack involve chemical weapon UN official stress importance wait official report inspector The inspector share finding UN SecretaryGeneral Ban Kimoon Ban say want wait UN team final report complete present UN Security Council The Organization Prohibition Chemical Weapons nine inspector belong say Saturday could take three week analyze evidence collect It need time able analyze information sample Nesirky say He note Ban repeatedly say alternative political solution crisis Syria military solution option Bergen Syria problem hell US Obama This menace must confront Obamas senior adviser debate next step take president comment Saturday come amid mount political pressure situation Syria Some US lawmaker call immediate action others warn step could become quagmire Some global leader express support British Parliaments vote military action earlier week blow Obamas hope get strong backing key NATO ally On Saturday Obama propose say would limited military action Syrian President Bashar alAssad Any military attack would openended include US ground force say Syrias allege use chemical weapon earlier month assault human dignity president say A failure respond force Obama argue could lead escalate use chemical weapon proliferation terrorist group would people harm In world many danger menace must confront Syria missile strike What would happen next Map US allied asset around Syria Obama decision come Friday night On Friday night president make lastminute decision consult lawmaker What happen vote Its unclear A senior administration official told CNN Obama authority act without Congress even Congress reject request authorization use force Obama Saturday continued shore support strike alAssad government He spoke phone French President Francois Hollande Rose Garden speech The two leader agree international community must deliver resolute message Assad regime others would consider use chemical weapon crime unacceptable violate international norm held accountable world White House say Meanwhile uncertainty loom Congress would weigh US military official say remain ready 5 key assertion US intelligence report Syria Syria Who want chemical weapon horror Reactions mixed Obamas speech A spokesman Syrian National Coalition say opposition group disappointed Obamas announcement Our fear lack action could embolden regime repeat attack serious way say spokesman Louay Safi So quite concerned Some member Congress applaud Obamas decision House Speaker John Boehner Majority Leader Eric Cantor Majority Whip Kevin McCarthy Conference Chair Cathy McMorris Rodgers issue statement Saturday praise president Under Constitution responsibility declare war lie Congress Republican lawmaker say We glad president seek authorization military action Syria response serious substantive question raise More 160 legislator include 63 Obamas fellow Democrats sign letter call either vote least full debate US action British Prime Minister David Cameron whose attempt get lawmaker country support military action Syria fail earlier week respond Obamas speech Twitter post Saturday I understand support Barack Obamas position Syria Cameron say An influential lawmaker Russia stood Syria criticize United States theory The main reason Obama turn Congress military operation get enough support either world among ally US United States Alexei Pushkov chairman internationalaffairs committee Russian State Duma say Twitter post In United States scatter group antiwar protester around country take street Saturday Like many Americanswere tire United States get involve invade bombing country say Robin Rosecrans among hundred Los Angeles demonstration What Syrias neighbor think Why Russia China Iran stand Assad Syrias government unfazed After Obamas speech military political analyst Syrian state TV say Obama embarrass Russia opposes military action Syria cry help someone come rescue face two defeat political military level Syrias prime minister appear unfazed saberrattling The Syrian Armys status maximum readiness finger trigger confront challenge Wael Nader alHalqi say meeting delegation Syrian expatriate Italy accord banner Syria State TV broadcast prior Obamas address An anchor Syrian state television say Obama appear prepare aggression Syria base repeat lie A top Syrian diplomat told state television network Obama face pressure take military action Israel Turkey Arabs rightwing extremist United States I think do well Cameron term take issue Parliament say Bashar Jaafari Syrias ambassador United Nations Both Obama Cameron say climbed top tree dont know get The Syrian government deny use chemical weapon August 21 attack say jihadist fight rebel use effort turn global sentiment British intelligence put number people kill attack 350 On Saturday Obama say told well 1000 people murder US Secretary State John Kerry Friday cite death toll 1429 400 child No explanation offer discrepancy Iran US military action Syria would spark disaster Opinion Why strike Syria bad idea"
inp_df = pd.DataFrame(columns=['text', 'summary'])
inp_df = inp_df.append({'text': str(input1), 'summary': ""}, ignore_index=True)
inp_df.head()

# %%
inp_df['text'] = inp_df['text'].apply(lambda x: re.sub(r'\(CNN\)|--|[^\w\s\.]','',x)).apply(lambda x: re.sub(r'(\.(?=[\s\r\n]|$))','',x)).apply(lambda x: re.sub(r'\n',' ',x)).apply(lambda x: re.sub(r'\.','',x))

# %%
# remove stop words
stop_words = set(stopwords.words('english'))
inp_df['text'] = inp_df['text'].apply(lambda x: nltk.word_tokenize(x)).apply(lambda x: " ".join([word for word in x if not word in stop_words]))

# %%
#lemmatize
lemmatization(inp_df['text'])
print(inp_df['text'])

# %%
seq = np.array(inp_df['text'])
print(seq)

# %%
seq_tokenizer = x_tokenizer.texts_to_sequences(seq)
#padding zero upto maximum length
seq_tokenizer_padded = pad_sequences(seq_tokenizer,  maxlen=max_text_len, padding='post')

gen_summary = decode_sequence(seq_tokenizer_padded)

original_txt = ' '.join(seq)

print("---")
print("Original: " + original_txt)
print("Generated Summary: " + gen_summary)
print("ROUGE score: ")
print(getRouge(summary, original_txt))
